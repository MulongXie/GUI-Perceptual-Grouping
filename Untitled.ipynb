# %%
import numpy as np
import pandas as pd
import json

from GUI import GUI

# %%
gui = GUI(img_file='data/input/4.jpg')

# %%
gui.detect_elements()
# Out:
# *** Please replace the Google OCR key at detect_text/ocr.py line 28 with your own (apply in https://cloud.google.com/vision) ***
# [Text Detection Completed in 1.591 s] data/input/4.jpg
# [Compo Detection Completed in 0.824 s] data/input/4.jpg
# Merge Complete and Save to data/output\uied\4.jpg Mon Jul 12 22:07:35 2021
# {'compos': [{'children': [{'class': 'Text',
#      'height': 17,
#      'position': {'column_max': 409,
#       'column_min': 345,
#       'row_max': 43,
#       'row_min': 26},
#      'text_content': 'newsbeast',
#      'width': 64},
#     {'class': 'Text',
#      'height': 15,
#      'position': {'column_max': 84,
#       'column_min': 70,
#       'row_max': 140,
#       'row_min': 125},
#      'text_content': '15',
#      'width': 14},
#     {'class': 'Text',
#      'height': 13,
#      'position': {'column_max': 322,
#       'column_min': 279,
#       'row_max': 136,
#       'row_min': 123},
#      'text_content': 'newsb',
#      'width': 43},
# ...
